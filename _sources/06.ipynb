# %% [markdown]
# # Day 6

# %%
data=File.read('6.txt').split("\n\n").map {|group| group.split("\n").map {|pers| pers.split("") }}
# Out:
# [[["v"], ["v", "x"], ["v"], ["v", "x"], ["n", "c", "l", "m", "b", "v"]], [["o", "d", "g", "p", "n", "w", "q", "x", "h", "b", "i", "t", "s"], ["p", "q", "w", "s", "n", "x", "i", "h", "o", "g", "d", "b", "t"], ["p", "o", "g", "i", "w", "x", "d", "h", "q", "b", "s", "n", "t"]], [["q"], ["o"]], [["a", "p", "u", "l", "n", "q", "r", "e", "s", "o", "h", "v", "k", "t", "x", "c", "y", "m", "z", "i", "b", "d", "w", "g"], ["s", "i", "g", "d", "v", "a", "k", "m", "l", "y", "x", "h", "e", "t", "o", "p", "n", "u", "b", "w", "z", "r", "q", "c"], ["i", "u", "s", "h", "n", "d", "t", "c", "l", "b", "e", "y", "o", "w", "x", "p", "q", "m", "k", "g", "z", "a", "v", "r"]], [["o", "w"], ["w", "o"]], [["p", "h", "e", "g", "q"], ["e", "q", "g", "p", "h"], ["h", "g", "p", "q", "u", "e"]], [["x", "i", "s", "p", "j", "z", "q"], ["s", "q", "k", "z", "c", "u", "p", "i"], ["i", "k", "s", "p", "q", "y", "z", "u", "e"]], [["h", "g", "f", "e", "s", "y", "v", "n"], ["d", "n", "s", "v", "t", "k", "h", "g", "l", "e", "a
# ...

# %%
data.map {|i| i.flatten.uniq.count }.sum
# Out:
# 6443

# %%
data.map {|i| i.inject(:&).count }.sum
# Out:
# 3232
